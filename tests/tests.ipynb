# %%
import yfinance as yf
from src.account import Account

# %%
data1 = yf.Ticker('ITX.MC')
data2 = yf.Ticker('KO')

# %%
data1.info['currentPrice']
# Out:
# 53.16

# %%
data.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2026, 10, 29),
#  'Earnings Date': [datetime.date(2026, 12, 2)],
#  'Earnings High': 0.55,
#  'Earnings Low': 0.526,
#  'Earnings Average': 0.5352,
#  'Revenue High': 11057000000,
#  'Revenue Low': 10790251730,
#  'Revenue Average': 10900997670}

# %%
data.history(period='1d',)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2026-09-22 00:00:00-04:00  87.599998  88.970001  87.455002  88.610001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-09-22 00:00:00-04:00  17226641        0.0           0.0

# %%
data.get_dividends(period='max')
# Out:
# Date
# 2002-07-26 00:00:00+02:00    0.022000
# 2002-09-25 00:00:00+02:00    0.027425
# 2003-07-24 00:00:00+02:00    0.028000
# 2004-07-22 00:00:00+02:00    0.101457
# 2005-07-21 00:00:00+02:00    0.096000
# 2005-09-27 00:00:00+02:00    0.008228
# 2006-07-21 00:00:00+02:00    0.134009
# 2006-09-26 00:00:00+02:00    0.011656
# 2007-08-01 00:00:00+02:00    0.168646
# 2007-09-25 00:00:00+02:00    0.011656
# 2008-08-01 00:00:00+02:00    0.210000
# 2008-09-25 00:00:00+02:00    0.006856
# 2009-05-04 00:00:00+02:00    0.110000
# 2009-11-02 00:00:00+01:00    0.100000
# 2010-05-03 00:00:00+02:00    0.120000
# 2010-11-02 00:00:00+01:00    0.136200
# 2011-05-02 00:00:00+02:00    0.160000
# 2011-11-02 00:00:00+01:00    0.160000
# 2012-05-02 00:00:00+02:00    0.180000
# 2012-11-02 00:00:00+01:00    0.180000
# 2013-05-02 00:00:00+02:00    0.220000
# 2013-11-04 00:00:00+01:00    0.220000
# 2014-05-02 00:00:00+02:00    0.242000
# 2014-11-03 00:00:00+01:00    0.242000
# ...
